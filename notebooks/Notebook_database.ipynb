# %% [markdown]
# #### Importamos las librerías necesarias

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# %% [markdown]
# #### Webscrapping de los tweets

# %%
#Definir las fechas
start_date = '2022-11-21'
end_date = '2023-03-07'

# %%
query = '@TheBridge_Tech since:{} until:{}'.format(start_date, end_date)

# %%
#Función para hacer el scrapping de los tweets

def scrape_tweets(query):
    tweets = []
    for tweet in sntwitter.TwitterSearchScraper(query).get_items():
        if tweet.user.username != 'TheBridge_Tech':
            tweet_id = tweet.id
            text = tweet.rawContent
            date = tweet.date.strftime('%Y-%m-%d %H:%M:%S')
            author_id = tweet.user.id
            author_name = tweet.user.displayname
            author_username = tweet.user.username
            retweets = tweet.retweetCount
            replies = tweet.replyCount
            likes = tweet.likeCount
            quotes = tweet.quoteCount
            tweets.append([tweet_id, text, date, author_id, author_name, author_username, retweets, replies, likes, quotes])
    return tweets

# %%
tweets = scrape_tweets(query)

# %%
# Convertir la lista de tweets en un dataframe
tweets_df = pd.DataFrame(tweets, columns=['id', 'text', 'date', 'author_id', 'author_name', 'author_username', 'retweets', 'replies', 'likes', 'quotes'])

# %%
tweets_df.shape
# Out:
# (128, 10)

# %%
#Dataframe de los tweets
df_tweets = pd.DataFrame(columns=['id', 'text', 'date', 'author_id', 'retweets_count', 'replies_count', 'likes_count', 'quotes_count'])
df_tweets['id'] = tweets_df['id']
df_tweets['text'] = tweets_df['text']
df_tweets['date'] = tweets_df['date']
df_tweets['author_id'] = tweets_df['author_id']
df_tweets['retweets_count'] = tweets_df['retweets']
df_tweets['replies_count'] = tweets_df['replies']
df_tweets['likes_count'] = tweets_df['likes']
df_tweets['quotes_count'] = tweets_df['quotes']

# %%
df_tweets['author_id'].nunique()
#Hay 56 users únicos
# Out:
# 56

# %%
#Dataframe de los users
df_users = tweets_df.loc[:, 'author_id':'author_username']

# %%
df_users.drop_duplicates(inplace=True)

# %%
df_users.shape
# Out:
# (56, 3)

# %% [markdown]
# #### Base de datos en AWS

# %%
#Credenciales AWS

username = "admin"
password = "pruebatecnica"
host = "technicaltest.cnvu29xw2umg.us-east-2.rds.amazonaws.com" 
port = 3306

# %%
#Conexión DB

db = pymysql.connect(host = host,
                     user = username,
                     password = password,
                     cursorclass = pymysql.cursors.DictCursor
)
cursor = db.cursor()

# %%
#Crear base de datos
create_db = '''CREATE DATABASE tweets_database'''
cursor.execute(create_db)
# Out:
# 1

# %%
#Seleccionar base de datos
cursor.connection.commit()
use_db = ''' USE tweets_database'''
cursor.execute(use_db)
# Out:
# 0

# %%
# Crear las tablas en la base de datos
cursor.execute('''
        CREATE TABLE tweets (
        id bigint PRIMARY KEY,
        text text,
        date timestamp,
        author_id bigint,
        retweets_count int,
        replies_count int,
        likes_count int,
        quotes_count int
        )
    ''')
cursor.execute('''
        CREATE TABLE users (
        author_id bigint PRIMARY KEY,
        author_name text,
        author_username text
        )
    ''')
# Out:
# 0

# %%
# Crear sqlalchemy engine

engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}".format(user = username, pw = password, host = host, db = 'tweets_database'))
# engine = create_engine("mysql+pymysql://my_user:my_password@my_host/my_database")

# %%
# Cargar los dataframes en las tablas correspondientes
df_tweets.to_sql(name='tweets', con=engine, if_exists= 'append', index=False)
df_users.to_sql(name='users', con=engine, if_exists= 'append', index=False)
# Out:
# 56

# %%
# Leer los datos para comprobar que se han ingestado correctamente
sql = '''SELECT * FROM tweets'''
cursor.execute(sql)
mi_tabla = cursor.fetchall()
mi_tabla
# Out:
# [{'id': 1594964278238654471,
#   'text': 'Aprende hoy las profesiones del futuro, ¡inscríbete en el #BBKBootcamp ⏩ https://t.co/uJcCKObkPz\n\nJunto con @TheBridge_Tech podrás aprender sobre Desarrollo Web Full Stack, Data Science, Ciberseguridad y Diseño de producto digital UX UI. https://t.co/wdbmRphsAx',
#   'date': datetime.datetime(2022, 11, 22, 8, 1, 31),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1594965197613322241,
#   'text': 'Ikasi gaur etorkizuneko lanbideak, izena eman #BBKBootcamp -ean ⏩ https://t.co/xvm6ekbcMQ\n\n@TheBridge_Tech -ekin batera,  Full Stack Web Garapena, Data Science, Zibersegurtasuna eta UX UI produktu digitalaren diseinuari buruz ikasteko aukera izango duzu. https://t.co/oxEOX35Osa',
#   'date': datetime.datetime(2022, 11, 22, 8, 5, 10),
#   'author_id': 702077405045899264,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1594968601265586178,
#   'text': 'Acelerando juntos el #talentodigital en España. El próximo 24 de noviembre, nuestro #CEO Juan Zamora presentará Hopla! en las instalaciones de .@TheBridge_Tech a las 17:30h. Contaremos quiénes somos, qué hacemos y cómo desarrollar una #carrerarofesional fructífera con nosotros. https://t.co/Sw9EUswIQ2',
#   'date': datetime.datetime(2022, 11, 22, 8, 18, 42),
#   'author_id': 783248945761910788,
#   'retweets_count': 1,
#   'replies_count': 1,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1595752907684843520,
#   'text': '🔵Acelera tu carrera digital con #BBKBootcamps.\n\nGracias a la colaboración entre @BBK_eus y @TheBridge_Tech podrás formarte con los mejores profesionales para lograr un trabajo con proyección.\n\n🔗Elige tu curso https://t.co/RxICpzj9N6\n\n#ux #developers #ciberseguridad #datascience',
#   'date': datetime.datetime(2022, 11, 24, 12, 15, 15),
#   'author_id': 823470817963032576,
#   'retweets_count': 3,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1597141474600050690,
#   'text': '@Cyber_Madrid  organiza el I Congreso de #Ciberseguridad para #pymes\n📅 14 de diciembre 2022\n🙍 modalidad presencial\n🏢 Palacio López-Dóriga, Pº de Recoletos, 15, Madrid (Sede de @TheBridge_Tech)\n🕤09.00h a 14.30h.\nInscríbete ya! Aforo limitado\n👇👇👇\nhttps://t.co/kH1Nf3p6jU https://t.co/qil8He6ZVV',
#   'date': datetime.datetime(2022, 11, 28, 8, 12, 55),
#   'author_id': 1407291884901482496,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1597490049087520769,
#   'text': '☕ Miércoles 30 NOV 9:00 @BAT_Tower Desayuno: La urgencia de cerrar la brecha de #talento digital en #Euskadi.\n➡ https://t.co/I5GS4SlhTR\n\n🍻 Jueves 1 DIC 18:30 @BBK_Kuna: Open Day BBK #Bootcamps by @TheBridge_Tech\n➡ https://t.co/zfkRFWmYmm\n\nNos allí!',
#   'date': datetime.datetime(2022, 11, 29, 7, 18, 2),
#   'author_id': 2402179123,
#   'retweets_count': 5,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1597626145289428992,
#   'text': 'Este Jueves 1 de diciembre a las 18:30 en @BBK_Kuna #Bilbao se presentan los BBK #Bootcamps by @TheBridge_Tech con especialidades en #FullStack #CiberSeguridad #DataAnalyst y #Ciberseguridad Inscíbete al evento y networking 🍻 https://t.co/o4y0MLPSsx',
#   'date': datetime.datetime(2022, 11, 29, 16, 18, 50),
#   'author_id': 2402179123,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1597626830764511232,
#   'text': 'Este Jueves 1 de diciembre a las 18:30 en @BBK_Kuna #Bilbao se presentan los BBK #Bootcamps by @TheBridge_Tech con especialidades en #FullStack #CiberSeguridad #DataAnalyst y #Ciberseguridad Inscríbete al evento y networking 🍻https://t.co/hLDF8paV6R',
#   'date': datetime.datetime(2022, 11, 29, 16, 21, 33),
#   'author_id': 378449449,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1597865610167439362,
#   'text': '🔛\xa0Día de presentación, @TheBridge_Tech y #BBK unimos fuerzas para presentaros la nueva edición de #BBKBootcamps. \n\n💻 Aprende hoy las profesiones del futuro. https://t.co/nYo8bnc77A',
#   'date': datetime.datetime(2022, 11, 30, 8, 10, 23),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1597866442841628672,
#   'text': '🔛 Aurkezpen eguna, @TheBridge_Tech eta #BBK -k indarrak batu ditugu #BBKBootcamps -en edizio berri honetan. \n\n💻 Ikasi gaur etorkizuneko lanbideak. https://t.co/jcQ2HM5g7Z',
#   'date': datetime.datetime(2022, 11, 30, 8, 13, 41),
#   'author_id': 702077405045899264,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1597868371663519744,
#   'text': '☕️🥐 Comienza la jornada con un desayuno de empresas. \n\nConstruye tu carrera en el sector digital con esta nueva edición de #BBKBootcamps. \n\nBBK 🤝 @TheBridge_Tech https://t.co/ORyNrF3uKI',
#   'date': datetime.datetime(2022, 11, 30, 8, 21, 21),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1597869451222913027,
#   'text': '☕️🥐 Jardunaldia enpresentzako gosariarekin hasi da @BAT_Tower -ean. \n\nEraiki zure karrera sektore digitalean #BBKBootcamps -en edizio berri honekin.  \n\nBBK 🤝 @TheBridge_Tech https://t.co/VILvbVXDUl',
#   'date': datetime.datetime(2022, 11, 30, 8, 25, 38),
#   'author_id': 702077405045899264,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1597873472679694336,
#   'text': '🗣 Nora Sarasola, Directora de Obra Social de BBK da comienzo a la jornada de presentación de #BBKBootcamps trayendo a #Euskadi el reto del talento para la industria 4.0, inclusión social y digital...\n\nBBK 🤝 @TheBridge_Tech https://t.co/84oRaLvEMq',
#   'date': datetime.datetime(2022, 11, 30, 8, 41, 37),
#   'author_id': 702077405045899264,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1597873965812285440,
#   'text': '🗣 Nora Sarasolak, BBK-ko Gizarte Ekintzako zuzendariak, hasiera eman dio jardunaldiari #Euskadi -ra talentuaren erronka ekarriz 4.0 industriarentzat, gizarteratze digitalarentzat...\n\nBBK 🤝 @TheBridge_Tech #BBKBootcamps https://t.co/6zqDJ61Dow',
#   'date': datetime.datetime(2022, 11, 30, 8, 43, 35),
#   'author_id': 702077405045899264,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1597875833699459072,
#   'text': '🗣 Continuamos con Iker Arce, CEO de @TheBridge_Tech nos presenta el contexto más global del gap de skills y puestos digitales con datos en el mundo, #Europa y en el marco comparado #España.\n\n#BBKBootcamps @BAT_Tower https://t.co/jM82e3AHyb',
#   'date': datetime.datetime(2022, 11, 30, 8, 51),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1597876414908432385,
#   'text': '🗣 Iker Arcerekin, @TheBridge_Tech -eko CEO-a, jarraitzen dugu. Oraingoan munduko gap skill-en eta postu digitalen testuinguru globalena aurkeztuko digu; Europan eta Espainian batik bat. \n\n#BBKBootcamps @BAT_Tower https://t.co/jx7YIVKG4G',
#   'date': datetime.datetime(2022, 11, 30, 8, 53, 19),
#   'author_id': 702077405045899264,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1597879796121407488,
#   'text': '🤔 ¿Qué son los #BBKBootcamps de BBK y @TheBridge_Tech? Son cursos de metodología Bootcamp de Desarrollo Web Full Stack, #DataScience, #Ciberseguridad y Diseño de Producto UX/UI. \n\nNora Sarasola nos los cuenta ⤵️ https://t.co/B9HflSDraZ',
#   'date': datetime.datetime(2022, 11, 30, 9, 6, 45),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1597880551578419201,
#   'text': '🤔 Zer dira BBK eta @TheBridge_Tech -en #BBKBootcamps -ak? Bootcamp metodologia ikastaroak dira Full Stack Web Garapenerako, Datuen Zientziarako, Zibersegurtasunerako eta UX/UI produktuen diseinurako.\n\nNora Sarasolak hobeto kontatzen digu hemen ⤵️ https://t.co/kqrKydUWTK',
#   'date': datetime.datetime(2022, 11, 30, 9, 9, 45),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1597886276056776704,
#   'text': '🗣 Tomás Iriondo, CEO de @ClusterGaia: "Tenemos que ayudar a la #pyme y para eso necesitamos crear #talento y en ese sentido este tipo de iniciativas como #BBKBootcamps, son ideales". \n\nBBK 🤝 @TheBridge_Tech https://t.co/CVrNCgJ1E5',
#   'date': datetime.datetime(2022, 11, 30, 9, 32, 30),
#   'author_id': 702077405045899264,
#   'retweets_count': 3,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1597886536896450562,
#   'text': '🗣 Tomás Iriondo, @ClusterGaia -ko CEO: "#ETEari lagundu behar diogu, eta, horretarako, #talentua sortu behar dugu. Horrelako ekimenak, hala nola #BBKBootcamp -ak, idealak dira.". \n\nBBK 🤝 @TheBridge_Tech https://t.co/AEJsNDQvHb',
#   'date': datetime.datetime(2022, 11, 30, 9, 33, 32),
#   'author_id': 702077405045899264,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1597889145497653249,
#   'text': '#BBKBootcamps | 🗣 Ramón Lozano, director de tecnología @ZucchettiSpain ⤵️ \n\nBBK 🤝 @TheBridge_Tech https://t.co/hIF239eTzi',
#   'date': datetime.datetime(2022, 11, 30, 9, 43, 54),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 1},
#  {'id': 1597889440789282817,
#   'text': 'Finaliza la jornada de presentación de la nueva edición de  #BBKBootcamps 👏 Eskerrik asko gurera gerturatu zareten guztioi! \n\nConstruye tu carrera en el sector digital ⏩ https://t.co/pqjWocmmpo\n\nBBK 🤝 @TheBridge_Tech https://t.co/D9FHwW771N',
#   'date': datetime.datetime(2022, 11, 30, 9, 45, 4),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 1},
#  {'id': 1597889537627283456,
#   'text': '#BBKBootcamps | 🗣 Guillermo Dorronso, Management Advisory Board @Zabala_IC ⤵️\n\nBBK 🤝 @TheBridge_Tech https://t.co/aBluTid7LN',
#   'date': datetime.datetime(2022, 11, 30, 9, 45, 27),
#   'author_id': 702077405045899264,
#   'retweets_count': 3,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 3},
#  {'id': 1597933210767433732,
#   'text': 'Open Day #Bilbao para conocer un #bootcam\n🗓️ 1/12/2022\n⏰ 18:30\n📍 @BBK_Kuna \n🗣️@jorgegrev\nby @TheBridge_Tech \nhttps://t.co/o2xcLzD8VM\nen @BBKnetwork \n🏷️#BBKBootcamps #Bizkaia #FullStack #Data #UX #Ciberseguridad',
#   'date': datetime.datetime(2022, 11, 30, 12, 39),
#   'author_id': 1951117790,
#   'retweets_count': 5,
#   'replies_count': 0,
#   'likes_count': 9,
#   'quotes_count': 0},
#  {'id': 1597982677675778048,
#   'text': 'guillerdorron: RT @BBK_eus: #BBKBootcamps | 🗣 Guillermo Dorronso, Management Advisory Board @Zabala_IC ⤵️\n\nBBK 🤝 @TheBridge_Tech https://t.co/3YeDuZwTna',
#   'date': datetime.datetime(2022, 11, 30, 15, 55, 34),
#   'author_id': 146406912,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1597982680087465984,
#   'text': 'guillerdorron: RT @BBK_eus: Finaliza la jornada de presentación de la nueva edición de  #BBKBootcamps 👏 Eskerrik asko gurera gerturatu zareten guztioi! \n\nConstruye tu carrera en el sector digital ⏩ https://t.co/8W7BQJ1sfv\n\nBBK 🤝 @TheBridge_Tech https://t.co/60teLII3Im',
#   'date': datetime.datetime(2022, 11, 30, 15, 55, 34),
#   'author_id': 146406912,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1597982684487340040,
#   'text': 'guillerdorron: RT @BBK_eus: 🤔 Zer dira BBK eta @TheBridge_Tech -en #BBKBootcamps -ak? Bootcamp metodologia ikastaroak dira Full Stack Web Garapenerako, Datuen Zientziarako, Zibersegurtasunerako eta UX/UI produktuen diseinurako.\n\nNora Sarasolak hobeto… https://t.co/UwIfXAaHZp',
#   'date': datetime.datetime(2022, 11, 30, 15, 55, 35),
#   'author_id': 146406912,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1598297264078098432,
#   'text': 'Esta tarde a las 18:30 tenemos la presentación de los #bbkbootcamps by @TheBridge_Tech en @BBK_Kuna \n\n➡️ ¡Pásate a conocernos! https://t.co/WlRFgaEZpv https://t.co/8M94pExTRH',
#   'date': datetime.datetime(2022, 12, 1, 12, 45, 37),
#   'author_id': 2402179123,
#   'retweets_count': 5,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1598305274309316609,
#   'text': '¿Quieres conocer todo sobre el #bootcamp de #DesarrolloWebFullStack de @TheBridge_Tech  y la @FundacionUc3  ?\n\nNo te pierdas la sesión informativa❗❗\n\n📅14 diciembre\n⏰17h.\n📍 Campus Madrid-Puerta de Toledo.\n💻 online.\n\n🎫Entrada #gratuita ➡ https://t.co/QiIRpb9108 https://t.co/rQ2WzDJMch',
#   'date': datetime.datetime(2022, 12, 1, 13, 17, 27),
#   'author_id': 2529499620,
#   'retweets_count': 3,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 1},
#  {'id': 1598345815583608832,
#   'text': '🔙 Ayer vivimos una jornada muy interesante en el evento de presentación de la nueva edición de #BBKBootcamps realizada en colaboración con @TheBridge_Tech en la @BAT_Tower. Muchas gracias a todas las personas que acudisteis a la presentación 🤗\n\n➕ℹ️  https://t.co/4tyJZlGVPW https://t.co/39Y275Hr5Y',
#   'date': datetime.datetime(2022, 12, 1, 15, 58, 32),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 1,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1598346448138956801,
#   'text': '🔙 Atzo oso jardunaldi interesgarria izan genuen @BAT_Tower -ean @TheBridge_Tech  -rekin elkarlanean egindako BBK Bootcamp-en edizio berria aurkezteko ekitaldian. Mila esker aurkezpenera etorri zineten guztioi 🤗 \n\nℹ️➕  https://t.co/oq37igkvIS https://t.co/ahuKUJ1IKY',
#   'date': datetime.datetime(2022, 12, 1, 16, 1, 3),
#   'author_id': 702077405045899264,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1598359807005802497,
#   'text': 'Especial agradecimiento a @sarasola_nora, Directora de Obra Social; @ikerarceseco, CEO de @TheBridge_Tech; @OAldayturriaga, Responsable de Educación, Talento y Emprendimiento; Tomas Iriondo, Director de @ClusterGaia; @guillerdorron de @Zabala_IC; y Ramon Lozano de @ZucchettiSpain',
#   'date': datetime.datetime(2022, 12, 1, 16, 54, 8),
#   'author_id': 702077405045899264,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1598597870797688833,
#   'text': '💡 Interesante intervención de Ramón Lozano, director de #Tecnologia de Zucchetti Spain, en la mesa redonda sobre la urgencia de cerrar la  brecha digital en Euskadi celebrada ayer.\n\nUna iniciativa de @BBK_eus @TheBridge_Tech\n\n#BeZucchetti\n@ZucchettiSpa @ZucchettiWorld',
#   'date': datetime.datetime(2022, 12, 2, 8, 40, 7),
#   'author_id': 108885393,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1599042965573599233,
#   'text': 'Agredecemos @TheBridge_Tech por acoger nuestro Meetup una vez mas! 🔥\n\nParece que los #Bitcoin ers pueden comportarse después de todo 😁\n\nMas sobre @TheBridge_Tech 👉https://t.co/BjzDxBd9to👈',
#   'date': datetime.datetime(2022, 12, 3, 14, 8, 46),
#   'author_id': 1530194743786881024,
#   'retweets_count': 4,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1599765621025169409,
#   'text': 'Tras la presentación de la nueva edición de #BBKBootcamps realizada en colaboración con @TheBridge_Tech en la torre @BAT_Tower, pudimos charlar con @guillerdorron \n de @Zabala_IC sobre cómo potenciar el #talento actual y cuáles son los perfiles tecnológicos más demandados. https://t.co/TIjvj3b4cL',
#   'date': datetime.datetime(2022, 12, 5, 14, 0, 20),
#   'author_id': 702077405045899264,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 7,
#   'quotes_count': 0},
#  {'id': 1599831430288359449,
#   'text': 'guillerdorron: RT @BBK_eus: Tras la presentación de la nueva edición de #BBKBootcamps realizada en colaboración con @TheBridge_Tech en la torre @BAT_Tower, pudimos charlar con @guillerdorron \n de @Zabala_IC sobre cómo potenciar el #talento actual y cuále… https://t.co/NEbbBGGc1x',
#   'date': datetime.datetime(2022, 12, 5, 18, 21, 51),
#   'author_id': 146406912,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1600067592143740931,
#   'text': 'En la presentación de los nuevos #BBKBootcamps realizada en colaboración @TheBridge_Tech en la @BAT_Tower, también charlamos con Ramón Lozano de @ZucchettiSpain sobre los principales problemas de #talento #digital que surgen en empresas tecnológicas y cómo afrontarlos. https://t.co/KUQR6CkCWQ',
#   'date': datetime.datetime(2022, 12, 6, 10, 0, 16),
#   'author_id': 702077405045899264,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1600198528323575809,
#   'text': 'Hoy llegó mi «Certificado de Graduación» en #fullstackdeveloper con @TheBridge_Tech , promovido por  @FUniversia  y  financiado por @IndraCompany / @minsaitbyindra  ¡Toca celebrar! https://t.co/LhqRBltkgm',
#   'date': datetime.datetime(2022, 12, 6, 18, 40, 34),
#   'author_id': 49219057,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 1,
#   'quotes_count': 1},
#  {'id': 1602215568127426562,
#   'text': '💡¡Interesante entrevista a nuestro Director de Tecnología Ramon Lozano sobre cómo afrontar los problemas de #talento #Digital en las empresas tecnológicas!\n\n🔽https://t.co/7a32ZHgefI\n\n#BeZucchetti #innovación #tecnología \n @BBK_eus @TheBridge_Tech \n@ZucchettiSpa @ZucchettiWorld',
#   'date': datetime.datetime(2022, 12, 12, 8, 15, 33),
#   'author_id': 108885393,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1602738464902250497,
#   'text': '@libertariadora @JavierAMaestre @kilrau @GaboHBeaumont @olya_borderless 🙏🏻 @TheBridge_Tech',
#   'date': datetime.datetime(2022, 12, 13, 18, 53, 22),
#   'author_id': 1530194743786881024,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1603702882209075200,
#   'text': 'No tenemos más que palabras de agradecimiento para nuestro anfitrión, @TheBridge_Tech cuyo Consejero Delegado, Iker Arce @ikerarceseco, intervino en la sesión inaugural del I Congreso de #ciberseguridad para #pymes del pasado 14 de diciembre. https://t.co/jTivSdsFA9',
#   'date': datetime.datetime(2022, 12, 16, 10, 45, 37),
#   'author_id': 1407291884901482496,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1605506556123963392,
#   'text': '#EDEMpoweredbyTheBridge la revolución formativa en tecnología.🤯 \n\n@TheBridge_Tech y #EDEM nos unimos para formar en profesiones que cambiarán vidas.\n\xa0\nEspecialízate en 4 #bootcamps intensivos sobre tecnología. 👩\u200d💻\n\xa0\nEste es el inicio del cambio. 👉 https://t.co/uobTtpxxaO https://t.co/AwJJ0mSHhY',
#   'date': datetime.datetime(2022, 12, 21, 10, 12, 46),
#   'author_id': 570795448,
#   'retweets_count': 3,
#   'replies_count': 0,
#   'likes_count': 6,
#   'quotes_count': 0},
#  {'id': 1605541094397198336,
#   'text': '💻 @EDEMempresarios y @TheBridge_Tech se alían para impartir bootcamps de desarrollo digital y tecnológico en València.\nhttps://t.co/M4vuwgM1qO',
#   'date': datetime.datetime(2022, 12, 21, 12, 30, 1),
#   'author_id': 402013017,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1605552650119847938,
#   'text': 'EDEM y The Bridge se alían para impartir bootcamps de desarrollo digital y tecnológico en Valencia https://t.co/IxzYpCc0Y6 \n@EDEMempresarios\n@marina_empresas\n@TheBridge_Tech\n#BootcampsDeDesarrolloDigitalyTecnológico',
#   'date': datetime.datetime(2022, 12, 21, 13, 15, 56),
#   'author_id': 1175646685,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 7,
#   'quotes_count': 0},
#  {'id': 1605865639213670400,
#   'text': '📚 Formación\n\n@EDEMempresarios y la aceleradora de talento digital @TheBridge_Tech se unen para impartir #bootcamps tecnológicos\n\nEl objetivo es reducir la brecha digital y potenciar la formación en competencias digitales y tecnológicas\n\n📪 @valenciaplaza\n\nhttps://t.co/ce6EiOTTil',
#   'date': datetime.datetime(2022, 12, 22, 9, 59, 38),
#   'author_id': 921670812637257728,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1606074933033009152,
#   'text': '. @EDEMempresarios y  @TheBridge_Tech se alían para impartir bootcamps de desarrollo digital y tecnológico en Valencia @marina_empresas ☛  https://t.co/LzsE3Tssvm #mediterráneopress #tudiariodigital #comunitatvalenciana #política #economía #empresa #turismo vía @MediterrneoPress',
#   'date': datetime.datetime(2022, 12, 22, 23, 51, 18),
#   'author_id': 799935450844631040,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1607662809575292929,
#   'text': 'Si estás buscando una profesión que te cambie la vida, acércate a nuestro Open Day donde presentaremos la alianza #EDEMpoweredbyTheBridge @TheBridge_Tech, una serie de bootcamps de desarrollo digital y tecnológico.\n\nhttps://t.co/NXRiXndJAD https://t.co/76bmkSVtzc',
#   'date': datetime.datetime(2022, 12, 27, 9, 0, 57),
#   'author_id': 570795448,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1608391421014196224,
#   'text': '@EDEMempresarios acoge el 12 de enero un Open Day en el que participan responsables de @TheBridge_Tech y de @EDEMempresarios para presentar los 4 bootcamps que acercarán a sus alumnos a profesiones con alta demanda\xa0\n\nhttps://t.co/ICzciLvWBo',
#   'date': datetime.datetime(2022, 12, 29, 9, 16, 11),
#   'author_id': 1128860148,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1608445776732246017,
#   'text': 'Los 4 bootcamps tecnológicos de EDEM y @TheBridge_Tech en los empleos más demandados 🔝\n\n▶ Data Science\n▶ Desarrollo Web Full Stack\n▶ UX/UI Product Design\n▶ Ciberseguridad\n\nToda la info ⬇\nhttps://t.co/hXDfJnLKPl',
#   'date': datetime.datetime(2022, 12, 29, 12, 52, 11),
#   'author_id': 570795448,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1608502937332113408,
#   'text': 'Empieza el año formándote en una de las profesiones con más 𝗱𝗲𝗺𝗮𝗻𝗱𝗮 𝗹𝗮𝗯𝗼𝗿𝗮𝗹. ⚠\n\nToma las riendas del 2023 y vente el 12/01 al Open Day donde te contaremos todo sobre los Bootcamps que te cambiarán la vida junto a @TheBridge_Tech. 🤯\n\nhttps://t.co/RnAcI6FUzc',
#   'date': datetime.datetime(2022, 12, 29, 16, 39, 19),
#   'author_id': 1151510939105144834,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1609931268921114627,
#   'text': '🤝 @EDEMempresarios se alía con @TheBridge_Tech para impartir bootcamps tecnológicos en #Valencia\n\nLa alianza busca reducir la brecha digital existente potenciando la formación tecnológica con más empleabilidad y demanda dentro del mercado laboral 🚀\nhttps://t.co/9zNT9BuCz3',
#   'date': datetime.datetime(2023, 1, 2, 15, 15),
#   'author_id': 874916978665938945,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1610606391445815297,
#   'text': '¡Empezamos el año con una #masterclass de #uxui! Introducción al diseño de #producto digital gracias a Jose Luis Tienza \n\n📅 Jueves 12 de enero a las 18:30h.\n🕐 1 hora\n👥 @BBK_Kuna, Urazurrutia Kalea 3, #Bilbao\nOrganiza: BBK Bootcamps by @TheBridge_Tech\n\nhttps://t.co/yHHKfmgJQ1',
#   'date': datetime.datetime(2023, 1, 4, 11, 57, 41),
#   'author_id': 2402179123,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1610652818234347521,
#   'text': '¿Te interesa el diseño de #producto digital? Ven a una #masterclass de #uxui gratuita gracias a #BBKbootcamps\n\n📅 Jueves 12 de enero a las 18:30h.\n🕐 1 hora\n👥 @BBK_Kuna, Urazurrutia Kalea 3, #Bilbao\nOrganiza: BBK Bootcamps by @TheBridge_Tech  https://t.co/T3xvMIT9My',
#   'date': datetime.datetime(2023, 1, 4, 15, 2, 11),
#   'author_id': 10279282,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1611338908196913153,
#   'text': 'Gracias a nuestros amigos @TheBridge_Tech por acogernos otra vez! 🙏',
#   'date': datetime.datetime(2023, 1, 6, 12, 28, 27),
#   'author_id': 1530194743786881024,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1611813891322908672,
#   'text': '🚀 @EDEMempresarios  y @TheBridge_Tech  se alían para impartir bootcamps de desarrollo digital y tecnológico en Valencia | Valientes Emprendedores https://t.co/OBYdVWWPQy',
#   'date': datetime.datetime(2023, 1, 7, 19, 55, 52),
#   'author_id': 271028835,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 7,
#   'quotes_count': 0},
#  {'id': 1612384123816910852,
#   'text': '¿Quieres desarrollar tu carrera en el mundo digital y tech?Te contamos cómo en el #OpenDay #Bootcamps con @TheBridge_Tech\n\nTe esperamos si te apasiona el mundo de la ciberseguridad, ciencia de datos, desarrollo de software o diseño de productos digitales👉https://t.co/NXRiXndJAD https://t.co/m10cly6Bgv',
#   'date': datetime.datetime(2023, 1, 9, 9, 41, 46),
#   'author_id': 570795448,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 2},
#  {'id': 1612429007739396097,
#   'text': 'Ya tenemos confirmado el sitio donde haremos el meetup de #CPS de la semana que viene. La gente de @TheBridge_Tech, en su infinita generosidad, vuelve a dejarnos su espacio.\n\nY también tenemos título para la charla de @ddamasd: "Las ingles".\n\n¡Nos vemos allí!',
#   'date': datetime.datetime(2023, 1, 9, 12, 40, 7),
#   'author_id': 1003872445,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 7,
#   'quotes_count': 0},
#  {'id': 1612763420998213635,
#   'text': '👨\u200d💻 Este 𝗷𝘂𝗲𝘃𝗲𝘀 𝗮 𝗹𝗮𝘀 𝟭𝟴:𝟯𝟬 𝗲𝗻 @BBK_Kuna  #Masterclass de diseño de producto digital #UXUI con Jose Luis Tienza.\n\nExplicaremos cómo #bbkbootcamps te pueden ayudar a ser un profesional digital gracias a @BBK_eus @TheBridge_Tech \n\n➡️Apúntate:\nhttps://t.co/yHHKfmgc0t https://t.co/3hWyHylVEb',
#   'date': datetime.datetime(2023, 1, 10, 10, 48, 57),
#   'author_id': 2402179123,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 1},
#  {'id': 1613453595323645952,
#   'text': 'HOY #masterclass de #UXUI Introducción al diseño de #producto digital con Jose Luis Tienza \n\n🕐 18:30h. en @BBK_Kuna, Urazurrutia Kalea 3, #Bilbao \n\nOrganiza: #BBKbootcamps by The Bridge\n@BBK_eus @TheBridge_Tech \n\nhttps://t.co/yHHKfmgc0t',
#   'date': datetime.datetime(2023, 1, 12, 8, 31, 28),
#   'author_id': 2402179123,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1613480908304048132,
#   'text': '🧐 ¿Quieres ser un profesional de la #ciberseguridad, el diseño de productos UX/UI, el Data Science o el desarrollo #FullStack?\n\nInscríbete al OpenDay de @EDEMempresarios powered by @TheBridge_Tech que se realizará hoy a las 18:00 en sus instalaciones 🤳\nhttps://t.co/Nwl3MnKFmU',
#   'date': datetime.datetime(2023, 1, 12, 10, 20),
#   'author_id': 874916978665938945,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1613519848339808262,
#   'text': '¿Quieres dedicarte al #desarrolloweb?\n¡Conéctate a nuestra sesión informativa y conoce nuestro #bootcamp junto @TheBridge_Tech !\n\n📆17 ene\n⏰17h\n💻Online\n\nEntrada gratuita 🎟\nhttps://t.co/y2a9xcIrxz\n\n#desarrollowebfullstack #programacionweb #backend #frontend https://t.co/fXjSfpXt1g',
#   'date': datetime.datetime(2023, 1, 12, 12, 54, 44),
#   'author_id': 2529499620,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1613822083259146240,
#   'text': 'Así fue la jornada de diseño de producto digital #uxui ayer en @BBK_Kuna impartida por José Luis Tienza de @TheBridge_Tech \n\nSi te quedaste con ganas de más aquí tienes nuestro #BBKbootcamp https://t.co/Yoq7FGIH1T https://t.co/W5eHltyp8X',
#   'date': datetime.datetime(2023, 1, 13, 8, 55, 42),
#   'author_id': 2402179123,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1614612463361695747,
#   'text': 'Advanced #Cynefin, Estuarine mapping &amp; EUFG Masterclass (Madrid) https://t.co/H5ZSjbKHAr | Los interesados en la aplicación de las ciencias de la complejidad en nuestro país tendremos la oportunidad de aprender de @snowded en persona el 16/3/23 en la sede de @TheBridge_Tech https://t.co/LavCfgYIht',
#   'date': datetime.datetime(2023, 1, 15, 13, 16, 23),
#   'author_id': 41545659,
#   'retweets_count': 51,
#   'replies_count': 7,
#   'likes_count': 326,
#   'quotes_count': 4},
#  {'id': 1614612464657653760,
#   'text': '@snowded @TheBridge_Tech Se trata de un taller avanzado, que cubre los últimos avances en los diferentes marcos desarrollados por @snowded , con especial mención del #Estuarine framework. https://t.co/8EVHVXGYmc , en mi opinión la aportación más importante hecha en 2022 en materia de #AppliedComplexity https://t.co/mUCg9eywvt',
#   'date': datetime.datetime(2023, 1, 15, 13, 16, 24),
#   'author_id': 41545659,
#   'retweets_count': 5,
#   'replies_count': 1,
#   'likes_count': 10,
#   'quotes_count': 0},
#  {'id': 1615279680126337025,
#   'text': '🎯¿Quieres saber cómo acelerar tu talento digital?\n \n¡Entonces no puedes perderte nuestra jornada de puertas abiertas de #Bootcamps que organiza @TheBridge_Tech!\n\n¡Te esperamos!⤵️\u200a\n\n📍Sede Formación (Calle Isabela, 1)\n📅\u200a26 de enero a las 18:00H\n📲\u200ahttps://t.co/LJXSoA2yR4 https://t.co/0mPVb2sQak',
#   'date': datetime.datetime(2023, 1, 17, 9, 27, 40),
#   'author_id': 163586106,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 1},
#  {'id': 1615326631807291392,
#   'text': '¿Sabes qué es un #𝗳𝘂𝗹𝗹𝘀𝘁𝗮𝗰𝗸 𝗱𝗲𝘃𝗲𝗹𝗼𝗽𝗲𝗿? ¿Te gusta la 𝗽𝗿𝗼𝗴𝗿𝗮𝗺𝗮𝗰𝗶𝗼́𝗻 #𝘄𝗲𝗯? El 𝗱𝗶́𝗮 𝟮𝟲 𝗲𝗻 @BBK_Kuna te invitamos a una #masterclass introductoria con @AlejandroRegex\n\nOrganizada por #BBKbootcamps @BBK_eus @TheBridge_Tech https://t.co/k3ghb3Ys92',
#   'date': datetime.datetime(2023, 1, 17, 12, 34, 14),
#   'author_id': 2402179123,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1615758687330791424,
#   'text': '@TheBridge_Tech Hola, estoy intentando entrar en la videoconferencia con vuestro enlace, pero no parece que funcione.',
#   'date': datetime.datetime(2023, 1, 18, 17, 11, 5),
#   'author_id': 1232105203,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1615772633773256706,
#   'text': 'En plena meet-up de CPS en @TheBridge_Tech con @ddamasd https://t.co/MkhnOh2Mzw',
#   'date': datetime.datetime(2023, 1, 18, 18, 6, 30),
#   'author_id': 7154412,
#   'retweets_count': 5,
#   'replies_count': 2,
#   'likes_count': 35,
#   'quotes_count': 1},
#  {'id': 1615774789850775558,
#   'text': '@Recuenco @TheBridge_Tech @ddamasd Qué suerte !!',
#   'date': datetime.datetime(2023, 1, 18, 18, 15, 4),
#   'author_id': 1610073819791728640,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1615776913410392065,
#   'text': 'Mira las rectas en el techo de las fotos de @modaquetepario y de @Recuenco. Puede que el máster de #CPS ayude a encontrar la forma de convertir las luminarias del techo de @TheBridge_Tech en #Madrid en la sede de la oficina donde está @modaquetepario https://t.co/ba848HlgZs',
#   'date': datetime.datetime(2023, 1, 18, 18, 23, 30),
#   'author_id': 212364786,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1615783265872510976,
#   'text': '@Recuenco @TheBridge_Tech @ddamasd Es tu master? Otra cosa?',
#   'date': datetime.datetime(2023, 1, 18, 18, 48, 45),
#   'author_id': 17287251,
#   'retweets_count': 0,
#   'replies_count': 2,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1615785967180201995,
#   'text': '@Godivaciones @Recuenco @TheBridge_Tech @ddamasd Meetup',
#   'date': datetime.datetime(2023, 1, 18, 18, 59, 29),
#   'author_id': 141272779,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1615786531943235599,
#   'text': '@Godivaciones @Recuenco @TheBridge_Tech @ddamasd Una charla de Diana en el marco de la comunidad CPS. Abierto a quien le apetezca ir',
#   'date': datetime.datetime(2023, 1, 18, 19, 1, 43),
#   'author_id': 417307513,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1615790291578929185,
#   'text': '@ae_bm @Recuenco @TheBridge_Tech @ddamasd Ya. Pregunto si está integrado en su máster (en colaboración con The Bridge) o es otra cosa distinta. Pero ahora creo recordar que el master CPS es online estricto.',
#   'date': datetime.datetime(2023, 1, 18, 19, 16, 40),
#   'author_id': 17287251,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1615792007909199872,
#   'text': '@Godivaciones @Recuenco @TheBridge_Tech @ddamasd creo que son independientes y el lugar del meetup puede variar',
#   'date': datetime.datetime(2023, 1, 18, 19, 23, 29),
#   'author_id': 141272779,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1615803069970714637,
#   'text': '@ae_bm @Godivaciones @TheBridge_Tech @ddamasd Eso es. Y está abierto a toda la comunidad, no hace falta que sean alumnos.',
#   'date': datetime.datetime(2023, 1, 18, 20, 7, 26),
#   'author_id': 7154412,
#   'retweets_count': 0,
#   'replies_count': 2,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1615804903854641156,
#   'text': '@Recuenco @ae_bm @TheBridge_Tech @ddamasd ✌️',
#   'date': datetime.datetime(2023, 1, 18, 20, 14, 43),
#   'author_id': 17287251,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1615807528398426126,
#   'text': '@Recuenco @ae_bm @TheBridge_Tech @ddamasd Una cosa, puede ir cualquiera-cualquiera? Porque se debe anunciar en algún sitio, y no sé quiénes son “la comunidad”. Los de las afueras de la comunidad cabemos? (Para cuando pueda…).',
#   'date': datetime.datetime(2023, 1, 18, 20, 25, 9),
#   'author_id': 17287251,
#   'retweets_count': 0,
#   'replies_count': 2,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1615809886566363136,
#   'text': '@Godivaciones @ae_bm @TheBridge_Tech @ddamasd Habla con @PauMugarra .',
#   'date': datetime.datetime(2023, 1, 18, 20, 34, 31),
#   'author_id': 7154412,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1615824135321526278,
#   'text': '@Recuenco @Godivaciones @ae_bm @TheBridge_Tech @ddamasd @PauMugarra Sobreentiendo que se refieren a este https://t.co/QJdYaEsjyF\n\nMeetup, es una App de gente que organiza quedadas temáticas. La mayor parte de gente no se conoce a priori, puede ser de cualquier tema, está en todo el mundo.\n\nAhora quiero también saber yo si es otra cosa.',
#   'date': datetime.datetime(2023, 1, 18, 21, 31, 9),
#   'author_id': 866742930,
#   'retweets_count': 0,
#   'replies_count': 2,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1615827851596505095,
#   'text': '@nudpiedo @Godivaciones @ae_bm @TheBridge_Tech @ddamasd @PauMugarra Es una reunión física de la comunidad CPS que gestiona @PauMugarra',
#   'date': datetime.datetime(2023, 1, 18, 21, 45, 55),
#   'author_id': 7154412,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1616010552110718982,
#   'text': '@nudpiedo @Recuenco @Godivaciones @ae_bm @TheBridge_Tech @ddamasd Gracias por esta aclaración Víctor.',
#   'date': datetime.datetime(2023, 1, 19, 9, 51, 54),
#   'author_id': 1003872445,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1616069260375195655,
#   'text': 'Un buen resumen de mi charla de ayer sobre vulnerabilidades en el proceso de #CPS en @TheBridge_Tech.',
#   'date': datetime.datetime(2023, 1, 19, 13, 45, 11),
#   'author_id': 91876265,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1616364270710853641,
#   'text': '❓ ¿Para quién es un #bootcamp? ¿Tengo que saber de tecnología previamente? ¿Qué me puede aportar si ya tengo un perfil tecnológico? En este vídeo encontrarás respuestas.\n\n➡ Un click para el cambio: https://t.co/vLc8dw80y6\n\n@TheBridge_Tech @BBK_Kuna @BBK_eus https://t.co/BSSdNSY87l',
#   'date': datetime.datetime(2023, 1, 20, 9, 17, 27),
#   'author_id': 2402179123,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1616488570008768514,
#   'text': '💥 Llega la @globalgamejam , a #42UrdulizFTef, única sede en Bizkaia del evento de desarrollo de #videojuegos 🎮 más grande del mundo 🌍\n\n🗓 3-5 FEB\n📍 42 Urduliz\n\nCon la colaboración de @DigiPenBilbao y @TheBridge_Tech @BBK_eus \n\n✍️ Inscríbete gratis en https://t.co/PV3kJn7Vvv https://t.co/IK9QGeuKeo',
#   'date': datetime.datetime(2023, 1, 20, 17, 31, 22),
#   'author_id': 1288769305014939650,
#   'retweets_count': 4,
#   'replies_count': 0,
#   'likes_count': 9,
#   'quotes_count': 0},
#  {'id': 1617455834924982272,
#   'text': 'Aprende hoy las profesiones del futuro 👨\u200d💻 Fórmate en #UxUiProductDesign, #DesarrolloWebFullStack, #DataScience y #Ciberseguridad con los bootcamps de @bbk_eus by @TheBridge_Tech y acelera tu carrera digital🚀\nMás info 👉 https://t.co/fMszTZfHld',
#   'date': datetime.datetime(2023, 1, 23, 9, 34, 56),
#   'author_id': 550417439,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1617466909334638592,
#   'text': 'Pero aquí no termina esto! Después de las charlas, podrás conocerlos y charlar con ellos, ya que compartiremos unas cañas 🍻 y haremos networking del bueno, además de que sólo por asistir tendrás la posibilidad de acceder a becas especiales de nuestro partner @TheBridge_Tech',
#   'date': datetime.datetime(2023, 1, 23, 10, 18, 56),
#   'author_id': 4899284631,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1617795268229070848,
#   'text': '📅Este jueves a las 18:30 en @BBK_Kuna #masterclass de desarrollo web #FullStack por @AlejandroRegex \n\nDescubre como introducirte al mundo de la #programación Web gracias a #BBKbootcamps \n\n@BBK_eus @TheBridge_Tech @BBKnetwork #Bilbao \n\n➡️Inscripción: https://t.co/k3ghb3Ys92 https://t.co/9JOy3bRRCp',
#   'date': datetime.datetime(2023, 1, 24, 8, 3, 43),
#   'author_id': 2402179123,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 2},
#  {'id': 1617986634817105922,
#   'text': 'Advanced #Cynefin, Estuarine mapping &amp; EUFG Masterclass (Madrid) https://t.co/H5ZSjbLfpZ | Los interesados en la aplicación de las ciencias de la complejidad en nuestro país tendremos la oportunidad de aprender de @snowded en persona el 16/3/23 en la sede de @TheBridge_Tech',
#   'date': datetime.datetime(2023, 1, 24, 20, 44, 9),
#   'author_id': 41545659,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1618594341152522243,
#   'text': '🎯¿Te gustaría acelerar tu #talento digital?\n \n¡Descubre las ventajas y oportunidades que ofrecen los #Bootcamps de @ENCamaraSevilla y @TheBridge_Tech, que se celebran en #Sevilla!\n\n🕞Hoy a las 18:00h➡️¡Todavía estás a tiempo de lanzar tu futuro!\n\nInfo:\n\nhttps://t.co/6uJDY9Hs1E https://t.co/rsbnVAP9Y1',
#   'date': datetime.datetime(2023, 1, 26, 12, 58, 57),
#   'author_id': 106344840,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1618630761564995585,
#   'text': '@nodosenlared @snowded @TheBridge_Tech Y eso es religión??',
#   'date': datetime.datetime(2023, 1, 26, 15, 23, 40),
#   'author_id': 1524905248007114783,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1618634157013467136,
#   'text': '📌 Hoy 26 de enero, tenemos el placer de participar en el Bootcamp de @TheBridge_Tech \n\nNuestro COO @javiercadierno hablará sobre empleabilidad en el marco actual\n\n🎁 Como novedad, también presentaremos una nueva Guía de Empleo que estará disponible en febrero \n\n¡Nos vemos!✌🏻',
#   'date': datetime.datetime(2023, 1, 26, 15, 37, 10),
#   'author_id': 1455515154133786625,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1618930569097748481,
#   'text': 'Se buscan personas para cambiar de vida 😎¿Listo para ser una de ellas? Dale un giro a tu carrera y entrénate en las profesiones más demandas con los bootcamps de @bbk_eus by @TheBridge_Tech 🚀 \n \n¿Quieres saber más? ➡ https://t.co/eVj9kI4yZH',
#   'date': datetime.datetime(2023, 1, 27, 11, 15),
#   'author_id': 550417439,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1618974318062624770,
#   'text': '🤝🏻 Un placer aportar nuestro granito de arena en el #bootcamp de @TheBridge_Tech \n\nGracias a todos los asistentes por la acogida, estamos ultimando detalles de nuestra Guía de Empleo para que la tengáis disponible a lo largo del mes de febrero 📌🎁\n\n¡Nos vemos pronto!😁 https://t.co/CLTRmUN9Ob',
#   'date': datetime.datetime(2023, 1, 27, 14, 8, 51),
#   'author_id': 1455515154133786625,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1619002323685998595,
#   'text': '¡Estudia ahora y paga cuando encuentres trabajo! Conviértete en experto digital con los #bootcamps de @bbk_eus by @TheBridge_Tech 👩\u200d💻 En formato full time o part time tardes, presencial o híbrido ¡tú decides! \n \nMás info ➡ https://t.co/eVj9kI4yZH',
#   'date': datetime.datetime(2023, 1, 27, 16, 0, 8),
#   'author_id': 550417439,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1619004022673018880,
#   'text': "@jorgegrev was one of the reasons I got into community. He has built countless communities/initiatives, brought tons of new folks into the ecosystem. He's currently rocking the @BBK_eus Bootcamp with @TheBridge_Tech helping unemployed people learn tech! https://t.co/m6QXoH6V69",
#   'date': datetime.datetime(2023, 1, 27, 16, 6, 53),
#   'author_id': 1101664008,
#   'retweets_count': 1,
#   'replies_count': 1,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1619236364343513088,
#   'text': 'Recordamos tb a las patrocinadoras PLATINO. Comprometidas desde el minuto cero y sin las cuales, este evento no sería lo que va a ser: ENORME 🥰 \n@plainconcepts @LifullConnEng  @bbk_eus by @TheBridge_Tech \n\nY KUDOS a @bilbao_udala @BilbaoEkintza como patrocinador principal https://t.co/bsxWeRkKGD',
#   'date': datetime.datetime(2023, 1, 28, 7, 30, 7),
#   'author_id': 550417439,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 5,
#   'quotes_count': 0},
#  {'id': 1620475795100831746,
#   'text': '@milmadrid_ @Ari_Reinventada @Gobuub @TheBridge_Tech @my_tech_plan @madridinnova @Puerta_Inno @LaNaveMadrid @MADRID Que interesante esto! Ya me apunté',
#   'date': datetime.datetime(2023, 1, 31, 17, 35, 11),
#   'author_id': 1437857235036786693,
#   'retweets_count': 0,
#   'replies_count': 2,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1620476763989250048,
#   'text': '@Yenito_ @milmadrid_ @Gobuub @TheBridge_Tech @my_tech_plan @madridinnova @Puerta_Inno @LaNaveMadrid @MADRID Nos vemos ahí😊😊',
#   'date': datetime.datetime(2023, 1, 31, 17, 39, 2),
#   'author_id': 1068424025356021760,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1620737818967576577,
#   'text': '@Yenito_ @milmadrid_ @Ari_Reinventada @Gobuub @TheBridge_Tech @madridinnova @Puerta_Inno @LaNaveMadrid @MADRID Que bueno! Nos vemos ahí!! 😊',
#   'date': datetime.datetime(2023, 2, 1, 10, 56, 22),
#   'author_id': 4899284631,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1621066894093733889,
#   'text': 'HOY a las 18:30 en @BBK_Kuna \n\n🧠🤖 Masterclass sobre Inteligencia Artificial #ChatGPT y otras IAs\n\nTambién explicaremos el #Bootcamp de #DataScience en #Bilbao \n\n@BBKnetwork @BBK_eus @TheBridge_Tech \n\nhttps://t.co/JiGdrdVPRf https://t.co/CBgyKBDtnm',
#   'date': datetime.datetime(2023, 2, 2, 8, 44),
#   'author_id': 2402179123,
#   'retweets_count': 4,
#   'replies_count': 0,
#   'likes_count': 6,
#   'quotes_count': 0},
#  {'id': 1621081485695385601,
#   'text': 'Nos hemos unido a @edemempresarios y @thebridge_tech para fomentar la formación en disciplinas digitales. 💻\n\nOfrecemos hasta 60 paquetes de ayudas para estudiar uno de los cuatro bootcamps impartidos en Valencia.\n\n¿Te vienes? 👉🏼 https://t.co/Ho6EwFqYen https://t.co/yKfKwXmTMq',
#   'date': datetime.datetime(2023, 2, 2, 9, 41, 59),
#   'author_id': 207894341,
#   'retweets_count': 3,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1621082634943365120,
#   'text': 'Interesantísima jornada de #ProptechThursdays con @TheFringeLABS @DavidHueso #propper #hanok @CasafariRE @IntrumES @TheBridge_Tech https://t.co/va4wjPTBnJ',
#   'date': datetime.datetime(2023, 2, 2, 9, 46, 33),
#   'author_id': 112458375,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1621199810345705473,
#   'text': '¿Una IA para gobernarlos a todos?\n@TheBridge_Tech https://t.co/CSeXEljxzF',
#   'date': datetime.datetime(2023, 2, 2, 17, 32, 9),
#   'author_id': 10279282,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1621201042368086017,
#   'text': 'Masterclass en Data Science de los BootCamps de BBK powered by @TheBridge_Tech #artificalintelligence #ChatGPT https://t.co/Mefh3L19Gk',
#   'date': datetime.datetime(2023, 2, 2, 17, 37, 3),
#   'author_id': 2218313375,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1621201435483426820,
#   'text': 'Inicia MasterClass #DataScience ¿una #IA para gobernarlos a todos? @TheBridge_Tech @BBK_Kuna @BBK_eus #AI #ChatGPT #NLP https://t.co/FfDRNdSetk',
#   'date': datetime.datetime(2023, 2, 2, 17, 38, 37),
#   'author_id': 1065627197115981824,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1621396098936864768,
#   'text': 'Un placer asistir ayer al "Taller UX/UI - Cómo maximizar el valor del usuario" impartido en @EDEMempresarios por @TheBridge_Tech  y Miriam Sánchez Muñoz 👏👏👏 https://t.co/sG2PeFjMYq',
#   'date': datetime.datetime(2023, 2, 3, 6, 32, 8),
#   'author_id': 2611663910,
#   'retweets_count': 1,
#   'replies_count': 1,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1622681492622127104,
#   'text': '@globalgamejam en #42UrdulizFTef, organizado con la colaboración de @DigiPenBilbao y BBK Bootcamps by @TheBridge_Tech\n\n70 jammers. 48 h. NON STOP.\n\n¿Quieres saber más sobre este eventazo? Visita nuestra web 👉 https://t.co/6vtlTFr4Yt\n\n#GGJ42FTef #GGJ #VideoGames #hackathon https://t.co/kBruFy1Atq',
#   'date': datetime.datetime(2023, 2, 6, 19, 39, 50),
#   'author_id': 1288769305014939650,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1622895716291997696,
#   'text': '¡Nuevo taller de #empleabilidad en #Sevilla junto a \n@InfoJobs! 💼\n\n¡En @ENCamaraSevilla abordaremos las nuevas #oportunidadeslaborales en el sector digital!\n\n📍 El 8 de febrero, a las 17:30h, en el Campus de @camaradesevilla con @TheBridge_Tech.\n\nInfo⤵️\n\nhttps://t.co/FFl1AV5DBf https://t.co/xUqEenBPZI',
#   'date': datetime.datetime(2023, 2, 7, 9, 51, 5),
#   'author_id': 106344840,
#   'retweets_count': 2,
#   'replies_count': 0,
#   'likes_count': 6,
#   'quotes_count': 0},
#  {'id': 1625126689150738438,
#   'text': 'Les compartimos un mini resumen del 1º encuentro de #reinventadxs\n\nY anunciamos que entramos en la cuenta regresiva del 2º, apúntate esta fecha: 30 de marzo.\n\n¿Te vemos en #Madrid?\n\nGracias a @thebridge_tech y el @milmadrid_ por hacerlo posible y nos vemos pronto!\n\n#mytechplan https://t.co/z5fwZzNR5w',
#   'date': datetime.datetime(2023, 2, 13, 13, 36, 10),
#   'author_id': 4899284631,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 1},
#  {'id': 1625813763751305216,
#   'text': 'Gracias a nuestros amigos @TheBridge_Tech por acogernos ayer en una manera bastante flexible, tenéis el equipo más adorable de todo Madrid! ♥️\n\nFue genial pasar San Valentín hablando #Bitcoin  🙏',
#   'date': datetime.datetime(2023, 2, 15, 11, 6, 22),
#   'author_id': 1530194743786881024,
#   'retweets_count': 2,
#   'replies_count': 1,
#   'likes_count': 10,
#   'quotes_count': 0},
#  {'id': 1626101043908993026,
#   'text': '@TheBridge_Tech @Vacolba @andresmacariog interesante',
#   'date': datetime.datetime(2023, 2, 16, 6, 7, 55),
#   'author_id': 1099588676181471233,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1626157411085033472,
#   'text': 'Buenos días CPSers!\nHoy podemos confirmar que el tercer meetup de la comunidad #CPS en Madrid será en @TheBridge_Tech. Agradecemos enormemente la generosidad de este espacio, y os esperamos el miércoles que viene!\n\nP.D: Aún quedan unas pocas plazas, estáis a tiempo de apuntaros',
#   'date': datetime.datetime(2023, 2, 16, 9, 51, 54),
#   'author_id': 1003872445,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 4,
#   'quotes_count': 0},
#  {'id': 1626267048434192385,
#   'text': '.@EstiLeon, Responsable del campus #42UrdulizFTef ya se encuentra participando de la mesa redonda - "Nuevos formatos en la formación" del @workinlansummit!\n\nCompartimos mesa con BBK Bootcamps by \n@TheBridge_Tech, IED KunsthalBilbao y @BBK_eus\n \n#WORKinlan #Bizkaia #Educación https://t.co/Iu6ZYqlFLz',
#   'date': datetime.datetime(2023, 2, 16, 17, 7, 33),
#   'author_id': 1288769305014939650,
#   'retweets_count': 5,
#   'replies_count': 1,
#   'likes_count': 10,
#   'quotes_count': 0},
#  {'id': 1626573019844907008,
#   'text': '@42UrdulizFTef @EstiLeon @workinlansummit @TheBridge_Tech @BBK_eus Hoy finaliza #WORKinlan y lo hace ya con una buena participación en Twitter y eso que aún queda todo el día de hoy 💪 https://t.co/54lcCbyUGi',
#   'date': datetime.datetime(2023, 2, 17, 13, 23, 22),
#   'author_id': 1685197165,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1626573673527234560,
#   'text': '@42UrdulizFTef @EstiLeon @workinlansummit @TheBridge_Tech @BBK_eus @PSEBizkaia @josebamondarain @grupo_ssi @socialistavasco @PSEBilbao @MtzGra @elcorreo_alava @elcorreo_com Muy buenas interacciones están teniendo las comunidades de las siguientes cuentas que copan el TOP 12 del #WORKinlan 🏆 https://t.co/g8SdZl1vL2',
#   'date': datetime.datetime(2023, 2, 17, 13, 25, 58),
#   'author_id': 1685197165,
#   'retweets_count': 0,
#   'replies_count': 1,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1630831255922114562,
#   'text': '@TheBridge_Tech @Vacolba , interesante',
#   'date': datetime.datetime(2023, 3, 1, 7, 24, 5),
#   'author_id': 1099588676181471233,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1631244101902270464,
#   'text': 'Este 14 de Marzo hay meetup en Madrid de @BitcoinTuesday_ , se va a hablar de un proyecto muy interesante para poder realizar desarrollos sobre Bitcoin. En breve se pasarán los detalles\nIr reservando el día y la hora, 7 PM en @TheBridge_Tech',
#   'date': datetime.datetime(2023, 3, 2, 10, 44, 35),
#   'author_id': 1207228796593745920,
#   'retweets_count': 11,
#   'replies_count': 2,
#   'likes_count': 21,
#   'quotes_count': 1},
#  {'id': 1631528154744406018,
#   'text': '@decentralized_b @BitcoinTuesday_ @TheBridge_Tech Que suspense! Miniscript?',
#   'date': datetime.datetime(2023, 3, 3, 5, 33, 19),
#   'author_id': 2603024598,
#   'retweets_count': 0,
#   'replies_count': 2,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1631548465649008640,
#   'text': '@rperezmarco @BitcoinTuesday_ @TheBridge_Tech No, espero que hoy nos digan y se comunique 😬😬 https://t.co/0rFMxwrlo6',
#   'date': datetime.datetime(2023, 3, 3, 6, 54, 1),
#   'author_id': 1207228796593745920,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1631600898777444354,
#   'text': 'Ya esta publicado el meetup de @BitcoinTuesday_ para este 14 de Marzo a las 7PM en @TheBridge_Tech \nMuy interesante:\n"Aplicaciones sobre Bitcoin con Agram Project!\nCrea aplicaciones sin necesidad de usar código, sobre el stack de tecnologías de Bitcoin"\n \nhttps://t.co/NQu4cxiPPh',
#   'date': datetime.datetime(2023, 3, 3, 10, 22, 22),
#   'author_id': 1207228796593745920,
#   'retweets_count': 4,
#   'replies_count': 0,
#   'likes_count': 11,
#   'quotes_count': 1},
#  {'id': 1631674245896982528,
#   'text': 'Hoy me llegó esta estupenda mochila y unos gadgets por pasar el RampUp del #Bootcamp de desarrollo web Gracias a @TheBridge_Tech por este detalle 😱🧑\u200d💻 #FullStackDeveloper https://t.co/0NY1BjTBHH',
#   'date': datetime.datetime(2023, 3, 3, 15, 13, 49),
#   'author_id': 763727449,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0},
#  {'id': 1631978537904222211,
#   'text': 'El meetup del jueves 9 de marzo con @ToniDorta se realizará finalmente @TheBridge_Tech 😄\nNos sentimos tremendamente agradecidos por su generosidad.\n¡Nos vemos este jueves!',
#   'date': datetime.datetime(2023, 3, 4, 11, 22, 58),
#   'author_id': 1003872445,
#   'retweets_count': 3,
#   'replies_count': 1,
#   'likes_count': 9,
#   'quotes_count': 1},
#  {'id': 1632020293509083137,
#   'text': '@PauMugarra @ToniDorta @TheBridge_Tech https://t.co/qv4oryC9i3',
#   'date': datetime.datetime(2023, 3, 4, 14, 8, 54),
#   'author_id': 276656109,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 2,
#   'quotes_count': 0},
#  {'id': 1632147141224275970,
#   'text': '@nodosenlared @snowded @TheBridge_Tech Muy buena foto desde el Círculo de Bellas Artes',
#   'date': datetime.datetime(2023, 3, 4, 22, 32, 56),
#   'author_id': 925597948410580993,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 1,
#   'quotes_count': 0},
#  {'id': 1632664546665025536,
#   'text': 'Encuentro de la @mlopscommunity en Madrid: "MLOPs: desde las trincheras" https://t.co/CHojEAs7ij en @TheBridge_Tech Ven a conocer la práctica #MLOps en Correcto., @Busuu @wallapop https://t.co/odie5CAuHU',
#   'date': datetime.datetime(2023, 3, 6, 8, 48, 56),
#   'author_id': 41545659,
#   'retweets_count': 1,
#   'replies_count': 0,
#   'likes_count': 3,
#   'quotes_count': 0},
#  {'id': 1632692120719859712,
#   'text': '¡Por fin podemos publicar el cartel con los ponentes para el #cybersecTalks! Si estás interesadx en alguna de las temáticas que aparecen no dudes en venir, es totalmente gratuito gracias al patrocinio de @TheBridge_Tech y la colaboración de @epsUPO @pablodeolavide \n(+ info abajo) https://t.co/JF85MDGmXc',
#   'date': datetime.datetime(2023, 3, 6, 10, 38, 30),
#   'author_id': 1585726199485140993,
#   'retweets_count': 3,
#   'replies_count': 1,
#   'likes_count': 5,
#   'quotes_count': 1},
#  {'id': 1632692123412594688,
#   'text': 'Las inscripciones se realizarán por Eventbrite. Cualquier duda estamos por MD o al correo info@esoliupo.es\nhttps://t.co/xhVr7VXcF3\n\n@epsUPO @TheBridge_Tech',
#   'date': datetime.datetime(2023, 3, 6, 10, 38, 30),
#   'author_id': 1585726199485140993,
#   'retweets_count': 0,
#   'replies_count': 0,
#   'likes_count': 0,
#   'quotes_count': 0}]

# %%
db.commit()

# %%
# Cerrar la conexión a la base de datos
db.close()

# %%
df_tweets.to_csv('data/tweets.csv')
df_users.to_csv('data/users.csv')
